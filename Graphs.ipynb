# %% [markdown]
# ## Imports etc.

# %%
from Initialisation import create_option
from PortfolioCreation import *
from GraphCreator import *
import matplotlib.pyplot as plt

# %% [markdown]
# ## Creating combinations

# %%
fly_102030_6m_low_vol = create_call_fly(strikes=[10,20,30], tte=0.5, vol=0.16)
calendar_3m_6m = create_call_calendar(strike=20, tte_1=0.25, tte_2=0.5, vol=0.16)
fly_102030_1m_low_vol = create_call_fly(strikes=[10,20,30], tte=1/12, vol=0.16)

# %% [markdown]
# ## Plotting graphs

# %%
plot_greeks(fly_102030_6m_low_vol, (5,35), 0.01)

# %%
plot_greeks(calendar_3m_6m, (10,30), 0.01)

# %%
plot_greeks(fly_102030_1m_low_vol, (5,35), 0.01)

# %%
plot_greeks_spot_fixed(spot= 10, tte=0.5, vol=0.16, strike_range=(1,20), step=0.01)
